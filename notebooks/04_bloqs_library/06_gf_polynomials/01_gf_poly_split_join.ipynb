# %% [markdown]
# # Polynomials over GF(p^m) - Split and Join
#
# [Official documentation](https://qualtran.readthedocs.io/en/latest/bloqs/gf_poly_arithmetic/gf_poly_split_and_join.html)

# %% [markdown]
# ### GFPolySplit

# %% [markdown]
# ### GFPolyJoin

# %% [markdown]
# # Bookkeeping Bloqs
#
# [Official documentation](https://qualtran.readthedocs.io/en/latest/bloqs/bookkeeping/bookkeeping.html)

# %% [markdown]
# ### Allocate

# %% [markdown]
# ### Free

# %% [markdown]
# ### Split

# %% [markdown]
# ### Join

# %% [markdown]
# ### Partition

# %% [markdown]
# ### Cast

# %% [markdown]
# ### AutoPartition

# %% [markdown]
# ### Always

# %% [markdown]
# # T Complexity Of Comparison Gates
#
# [Official documentation](https://qualtran.readthedocs.io/en/latest/bloqs/arithmetic/t_complexity_of_comparison_gates.html)

# %% [markdown]
# ### T Complexity Of Comparison Gates

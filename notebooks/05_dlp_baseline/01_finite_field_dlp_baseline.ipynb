# %% [markdown]
# # Finite-Field DLP Baseline
#
# [Official documentation](https://qualtran.readthedocs.io/en/latest/bloqs/gf_arithmetic/gf2_multiplication.html)

# %% [markdown]
# ### Build a Small-m DLP Bloq

# %% [markdown]
# ### Classical Simulation

# %% [markdown]
# ### Call Graph

# %% [markdown]
# ### Logical Qubit Count

# %% [markdown]
# ### Logical Gate Cost

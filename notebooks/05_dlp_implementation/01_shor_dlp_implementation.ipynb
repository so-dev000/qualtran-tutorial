# %% [markdown]
# # GF(p^r) Shor-DLP Implementation
#
# [Official documentation](https://qualtran.readthedocs.io/en/latest/bloqs/gf_arithmetic/gf2_multiplication.html)

# %% [markdown]
# ### GF(p^r) Element Representation

# %% [markdown]
# ### F_p Coefficient Registers

# %% [markdown]
# ### Multiplication by a Known c in GF(p^r)

# %% [markdown]
# ### Controlled Multiplication by c

# %% [markdown]
# ### Shor-DLP Root Bloq

# %% [markdown]
# ### Classical Simulation

# %% [markdown]
# ### Call Graph

# %% [markdown]
# ### Qubit and Gate Resource Counting

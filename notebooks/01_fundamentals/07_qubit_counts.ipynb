# %% [markdown]
# # Qubit Counts
#
# 公式ドキュメント「Fundamentals」対応ノートブック
#
# 対応する公式ページ: [Qubit Counts (Fundamentals)](https://qualtran.readthedocs.io/en/latest/resource_counting/qubit_counts.html)
#
# ## 概要
#
# (ここに内容を記述)

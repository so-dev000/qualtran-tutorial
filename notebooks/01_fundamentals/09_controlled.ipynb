# %% [markdown]
# # Controlled (制御)
#
# 公式ドキュメント「Fundamentals」対応ノートブック
#
# 対応する公式ページ: [Controlled (制御) (Fundamentals)](https://qualtran.readthedocs.io/en/latest/Controlled.html)
#
# ## 概要
#
# (ここに内容を記述)

# %% [markdown]
# # Multiplication
#
# [Official documentation](https://qualtran.readthedocs.io/en/latest/bloqs/arithmetic/multiplication.html)

# %% [markdown]
# ### PlusEqualProduct

# %% [markdown]
# ### Product

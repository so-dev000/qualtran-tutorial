# %% [markdown]
# # Comparison
#
# [Official documentation](https://qualtran.readthedocs.io/en/latest/bloqs/arithmetic/comparison.html)

# %% [markdown]
# ### GreaterThan

# %% [markdown]
# ### GreaterThanConstant

# %% [markdown]
# ### LessThanConstant

# %% [markdown]
# # Modular Subtraction
#
# [Official documentation](https://qualtran.readthedocs.io/en/latest/bloqs/mod_arithmetic/mod_subtraction.html)

# %% [markdown]
# ### ModNeg

# %% [markdown]
# ### CModNeg

# %% [markdown]
# ### ModSub

# %% [markdown]
# ### CModSub

# %% [markdown]
# # Factoring RSA
#
# [Official documentation](https://qualtran.readthedocs.io/en/latest/bloqs/cryptography/rsa/rsa.html)

# %% [markdown]
# ### ModExp

# %% [markdown]
# ### RSAPhaseEstimate

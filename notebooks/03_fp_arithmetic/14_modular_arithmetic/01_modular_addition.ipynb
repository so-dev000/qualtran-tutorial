# %% [markdown]
# # Modular Addition
#
# [Official documentation](https://qualtran.readthedocs.io/en/latest/bloqs/mod_arithmetic/mod_addition.html)

# %% [markdown]
# ### ModAdd

# %% [markdown]
# ### ModAddK

# %% [markdown]
# ### CModAdd

# %% [markdown]
# ### CModAddK

# %% [markdown]
# ### CtrlScaleModAdd

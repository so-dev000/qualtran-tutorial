# %% [markdown]
# # Interop with Microsoft Resource Estimator
#
# [Official documentation](https://qualtran.readthedocs.io/en/latest/surface_code/msft_resource_estimator_interop.html)

# %% [markdown]
# ### Microsoft Resource Estimator Interoperability

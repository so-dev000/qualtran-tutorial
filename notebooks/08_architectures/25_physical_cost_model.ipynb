# %% [markdown]
# # Architecture-dependent physical costs
#
# [Official documentation](https://qualtran.readthedocs.io/en/latest/surface_code/physical_cost_model.html)

# %% [markdown]
# ### PhysicalCostModel

# %% [markdown]
# ### DataBlock

# %% [markdown]
# ### MagicStateFactory

# %% [markdown]
# ### QECScheme

# %% [markdown]
# ### PhysicalParameters

# %% [markdown]
# ### Modeling details

# %% [markdown]
# ### Mixing and Matching

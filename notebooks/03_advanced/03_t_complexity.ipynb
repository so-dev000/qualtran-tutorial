# %% [markdown]
# # T-complexity
#
# 公式ドキュメント「Advanced Topics」対応ノートブック
#
# 対応する公式ページ: [T-complexity (Advanced Topics)](https://qualtran.readthedocs.io/en/latest/cirq_interop/t_complexity.html)
#
# ## 概要
#
# (ここに内容を記述)

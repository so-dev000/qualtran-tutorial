# %% [markdown]
# # Gate with Registers
#
# 公式ドキュメント「Advanced Topics」対応ノートブック
#
# 対応する公式ページ: [Gate with Registers (Advanced Topics)](https://qualtran.readthedocs.io/en/latest/_infra/gate_with_registers.html)
#
# ## 概要
#
# (ここに内容を記述)

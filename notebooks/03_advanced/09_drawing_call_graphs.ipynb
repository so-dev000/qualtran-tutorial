# %% [markdown]
# # Call Graph の図示
#
# 公式ドキュメント「Advanced Topics」対応ノートブック
#
# 対応する公式ページ: [Call Graph の図示 (Advanced Topics)](https://qualtran.readthedocs.io/en/latest/drawing/drawing_call_graph.html)
#
# ## 概要
#
# (ここに内容を記述)

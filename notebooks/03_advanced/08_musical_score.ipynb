# %% [markdown]
# # Musical Score (楽譜形式の図示)
#
# 公式ドキュメント「Advanced Topics」対応ノートブック
#
# 対応する公式ページ: [Musical Score (楽譜形式の図示) (Advanced Topics)](https://qualtran.readthedocs.io/en/latest/drawing/musical_score.html)
#
# ## 概要
#
# (ここに内容を記述)

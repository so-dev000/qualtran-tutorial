# %% [markdown]
# # 特殊化された制御実装と随伴の伝播
#
# 公式ドキュメント「Advanced Topics」対応ノートブック
#
# 対応する公式ページ: [特殊化された制御実装と随伴の伝播 (Advanced Topics)](https://qualtran.readthedocs.io/en/latest/bloqs/mcmt/specialized_ctrl.html)
#
# ## 概要
#
# (ここに内容を記述)

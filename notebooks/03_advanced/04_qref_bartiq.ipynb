# %% [markdown]
# # Qualtran + QREF & Bartiq
#
# 公式ドキュメント「Advanced Topics」対応ノートブック
#
# 対応する公式ページ: [Qualtran + QREF & Bartiq (Advanced Topics)](https://qualtran.readthedocs.io/en/latest/qref_interop/bartiq_demo.html)
#
# ## 概要
#
# (ここに内容を記述)

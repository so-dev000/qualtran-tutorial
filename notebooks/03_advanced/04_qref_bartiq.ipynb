# %% [markdown]
# # Qualtran + QREF & Bartiq
#
# [Official documentation](https://qualtran.readthedocs.io/en/latest/qref_interop/bartiq_demo.html)

# %% [markdown]
# ### QREF

# %% [markdown]
# ### Bartiq Resource Estimation

# %% [markdown]
# # CompositeBloq の操作
#
# 公式ドキュメント「Advanced Topics」対応ノートブック
#
# 対応する公式ページ: [CompositeBloq の操作 (Advanced Topics)](https://qualtran.readthedocs.io/en/latest/_infra/composite_bloq.html)
#
# ## 概要
#
# (ここに内容を記述)

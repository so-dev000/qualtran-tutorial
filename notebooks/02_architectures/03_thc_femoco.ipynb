# %% [markdown]
# # THC FeMoco コンパイル
#
# 公式ドキュメント「Quantum Computer Architectures」対応ノートブック
#
# 対応する公式ページ: [THC FeMoco コンパイル (Quantum Computer Architectures)](https://qualtran.readthedocs.io/en/latest/surface_code/thc_compilation.html)
#
# ## 概要
#
# (ここに内容を記述)

# %% [markdown]
# # アーキテクチャ依存の物理コスト
#
# 公式ドキュメント「Quantum Computer Architectures」対応ノートブック
#
# 対応する公式ページ: [アーキテクチャ依存の物理コスト (Quantum Computer Architectures)](https://qualtran.readthedocs.io/en/latest/surface_code/physical_cost_model.html)
#
# ## 概要
#
# (ここに内容を記述)

# %% [markdown]
# # Beverland et al. モデル
#
# 公式ドキュメント「Quantum Computer Architectures」対応ノートブック
#
# 対応する公式ページ: [Beverland et al. モデル (Quantum Computer Architectures)](https://qualtran.readthedocs.io/en/latest/surface_code/beverland_et_al_model.html)
#
# ## 概要
#
# (ここに内容を記述)

# %% [markdown]
# # Beverland et al. Model
#
# [Official documentation](https://qualtran.readthedocs.io/en/latest/surface_code/beverland_et_al_model.html)

# %% [markdown]
# ### The Inputs

# %% [markdown]
# ### Resource Estimation

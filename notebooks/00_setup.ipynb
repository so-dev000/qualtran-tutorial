# %% [markdown]
# # Setup and Sanity Check
#
# [Official documentation](https://qualtran.readthedocs.io/en/latest/index.html)

# %% [markdown]
# ### Installation

# %% [markdown]
# ### Environment Check

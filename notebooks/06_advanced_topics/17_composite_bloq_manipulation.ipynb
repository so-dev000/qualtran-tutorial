# %% [markdown]
# # Composite Bloq Manipulation
#
# [Official documentation](https://qualtran.readthedocs.io/en/latest/_infra/composite_bloq.html)

# %% [markdown]
# ### Bloq Builder

# %% [markdown]
# ### Decompose Bloq

# %% [markdown]
# ### Valid Decomposition

# %% [markdown]
# ### Flatten

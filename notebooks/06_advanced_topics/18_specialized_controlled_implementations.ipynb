# %% [markdown]
# # Bloqs with Specialized Controlled Implementations
#
# [Official documentation](https://qualtran.readthedocs.io/en/latest/bloqs/mcmt/specialized_ctrl.html)

# %% [markdown]
# ### Specialized Controlled Implementations

# %% [markdown]
# # Cross-checking Classical Simulation
#
# [Official documentation](https://qualtran.readthedocs.io/en/latest/simulation/xcheck_classical_quimb.html)

# %% [markdown]
# ### XGate

# %% [markdown]
# ### CNOT

# %% [markdown]
# ### Toffoli

# %% [markdown]
# ### Add
